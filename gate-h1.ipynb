# %%
import os
from google import genai

api_key = os.environ.get("GEMINI_API_KEY")

if not api_key:
    raise ValueError("GEMINI_API_KEY not found in environment variables.")

client = genai.Client(api_key=api_key)

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",
    contents="In one sentence, explain simply what artificial neural networks is?"
)

print(response.text)
# Out:
# An artificial neural network is a computer system inspired by the human brain that learns to recognize patterns and solve problems by processing large amounts of data.

# %%
from google.genai import types
import json

response = client.models.generate_content(
    model="gemini-flash-latest",
    contents="Give me 3 core concepts behind transformer-based LLMs, each with a one-sentence explanation.",
    config=types.GenerateContentConfig(
        response_mime_type="application/json",
        response_schema={
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "concept": {"type": "string"},
                    "explanation": {"type": "string"}
                },
                "required": ["concept", "explanation"]
            }
        }
    )
)

data = json.loads(response.text)
print(json.dumps(data, indent=2))
# Out:
# [
#   {
#     "concept": "Self-Attention Mechanism",
#     "explanation": "It enables the model to weigh the importance of different words in a sequence relative to one another, capturing complex contextual relationships regardless of their distance."
#   },
#   {
#     "concept": "Positional Encoding",
#     "explanation": "It injects information about the sequential order of words into the embeddings, compensating for the transformer's parallel processing that inherently lacks sequence awareness."
#   },
#   {
#     "concept": "Multi-Head Attention",
#     "explanation": "It allows the model to jointly attend to information from different representation subspaces at once, enriching the depth of learned contextual representations."
#   }
# ]

# %%
print(data)
# Out:
# [{'concept': 'Self-Attention Mechanism', 'explanation': 'It enables the model to weigh the importance of different words in a sequence relative to one another, capturing complex contextual relationships regardless of their distance.'}, {'concept': 'Positional Encoding', 'explanation': "It injects information about the sequential order of words into the embeddings, compensating for the transformer's parallel processing that inherently lacks sequence awareness."}, {'concept': 'Multi-Head Attention', 'explanation': 'It allows the model to jointly attend to information from different representation subspaces at once, enriching the depth of learned contextual representations.'}]
